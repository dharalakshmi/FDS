# %% [markdown]
# <a href="https://colab.research.google.com/github/dharalakshmi/FDS/blob/main/fds_part3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.stats import levene
from scipy.stats import kruskal
from scipy.stats import pearsonr, spearmanr

#step 1
df = pd.read_excel('/mnt/Eyeshadow_final.xlsx')
sentiment_scores = df['sentiment'].values
# Replace 'sentiment_column' with your actual column name
# Define your benchmark value
benchmark_value = 0.0 # Example benchmark, use this
# Perform the one-sample t-test
mean_score = np.mean(sentiment_scores)
std_dev = np.std(sentiment_scores, ddof=1) # Sample standard deviation
n = len(sentiment_scores)


#step 2
# Assuming you have your sentiment scores in a Pandas DataFrame
sentiment_scores = df['sentiment']
# Shapiro-Wilk Test
stat, p_value = shapiro(sentiment_scores)
print(f"\nShapiro-Wilk Test Statistic: {stat:.4f}, P-Value: {p_value:.4f}")
# Interpret the p-value
if p_value > 0.05:
 print("Data is normally distributed (Fail to reject H0).")
else:
 print("Data is not normally distributed (Reject H0).")
print()
# Q-Q Plot
plt.figure(figsize=(6, 4))
stats.probplot(sentiment_scores, dist="norm", plot=plt)
plt.show()
# Histogram
plt.figure(figsize=(6, 4))
print()
sns.histplot(sentiment_scores, kde=True)
plt.show()


#step 3
# Assuming you have sentiment scores grouped by database
grouped_sentiments = [group['sentiment'] for name, group in df.groupby('Website')]
# Levene's Test for equal variances
stat, p_value = levene(*grouped_sentiments)
print(f"\nLevene's Test Statistic: {stat:.4f}, P-Value: {p_value:.4f}")
# Interpret the p-value
if p_value > 0.05:
 print("Variances are equal (Fail to reject H0).")
else:
 print("Variances are not equal (Reject H0).")


#step 4
h_statistic, kruskal_p_value = kruskal(*grouped_sentiments)
print(f"Kruskal-Wallis H Statistic: {h_statistic:.4f}, P-Value:{kruskal_p_value:.4f}")
if kruskal_p_value < 0.05:
  print("Reject the null hypothesis: There is a significant difference between the groups.")
else:
  print("Fail to reject the null hypothesis: No significant difference between the groups.")


#step 5
# Create additional variables if needed
# For example, calculate the comment length if it's not already in your data
df['comment_length'] = df['Comment'].apply(len)
# Checking correlations between sentiment and comment length
pearson_corr, pearson_p_value = pearsonr(df['sentiment'], df['comment_length'])
spearman_corr, spearman_p_value = spearmanr(df['sentiment'], df['comment_length'])
print(f"Pearson Correlation between Sentiment and Comment Length: {pearson_corr:.4f},P-Value: {pearson_p_value:.4f}")
print(f"Spearman Correlation between Sentiment and Comment Length:{spearman_corr:.4f}, P-Value: {spearman_p_value:.4f}")
print()
# Visualizing the correlation with a scatter plot
plt.figure(figsize=(6, 4))
sns.scatterplot(x='comment_length', y='sentiment', data=df)
plt.title('Scatter Plot of Sentiment vs. Comment Length')
plt.show()
print()

#step 5
# Scatter plot with Pearson correlation line
plt.figure(figsize=(6, 4))
sns.scatterplot(x='comment_length', y='sentiment', data=df, alpha=0.5)
sns.regplot(x='comment_length', y='sentiment', data=df, scatter=False, color='r')
plt.title(f'Scatter Plot with Pearson Correlation (r={pearson_corr:.2f})')
plt.xlabel('Comment Length')
plt.ylabel('Sentiment')
plt.show()
print()
# Scatter plot with Spearman correlation line (non-parametric)
plt.figure(figsize=(6, 4))
sns.scatterplot(x='comment_length', y='sentiment', data=df, alpha=0.5)
sns.lineplot(x='comment_length', y='sentiment',
data=df.sort_values(by='comment_length'), color='r')
plt.title(f'Scatter Plot with Spearman Correlation (rho={spearman_corr:.2f})')
plt.xlabel('Comment Length')
plt.ylabel('Sentiment')
plt.show()
# Out:
# Shapiro-Wilk Test Statistic: 0.3732, P-Value: 0.0000
# Data is not normally distributed (Reject H0).
# Levene's Test Statistic: 1.2563, P-Value: 0.2856
# Variances are equal (Fail to reject H0).
# Kruskal-Wallis H Statistic: 5.0194, P-Value:0.2853
# Fail to reject the null hypothesis: No significant difference between the groups.
# Pearson Correlation between Sentiment and Comment Length: -0.1424,P-Value: 0.0000
# Spearman Correlation between Sentiment and Comment Length:-0.0723, P-Value: 0.0302

# %%
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.stats import levene
from scipy.stats import kruskal
from scipy.stats import pearsonr, spearmanr

#step 1
df = pd.read_excel('/mnt/LipKit_final.xlsx')
sentiment_scores = df['sentiment'].values
# Replace 'sentiment_column' with your actual column name
# Define your benchmark value
benchmark_value = 0.0 # Example benchmark, use this
# Perform the one-sample t-test
mean_score = np.mean(sentiment_scores)
std_dev = np.std(sentiment_scores, ddof=1) # Sample standard deviation
n = len(sentiment_scores)


#step 2
# Assuming you have your sentiment scores in a Pandas DataFrame
sentiment_scores = df['sentiment']
# Shapiro-Wilk Test
stat, p_value = shapiro(sentiment_scores)
print(f"\nShapiro-Wilk Test Statistic: {stat:.4f}, P-Value: {p_value:.4f}")
# Interpret the p-value
if p_value > 0.05:
 print("Data is normally distributed (Fail to reject H0).")
else:
 print("Data is not normally distributed (Reject H0).")
print()
# Q-Q Plot
plt.figure(figsize=(6, 4))
stats.probplot(sentiment_scores, dist="norm", plot=plt)
plt.show()
# Histogram
plt.figure(figsize=(6, 4))
print()
sns.histplot(sentiment_scores, kde=True)
plt.show()


#step 3
# Assuming you have sentiment scores grouped by database
grouped_sentiments = [group['sentiment'] for name, group in df.groupby('Website')]
# Levene's Test for equal variances
stat, p_value = levene(*grouped_sentiments)
print(f"\nLevene's Test Statistic: {stat:.4f}, P-Value: {p_value:.4f}")
# Interpret the p-value
if p_value > 0.05:
 print("Variances are equal (Fail to reject H0).")
else:
 print("Variances are not equal (Reject H0).")


#step 4
h_statistic, kruskal_p_value = kruskal(*grouped_sentiments)
print(f"Kruskal-Wallis H Statistic: {h_statistic:.4f}, P-Value:{kruskal_p_value:.4f}")
if kruskal_p_value < 0.05:
  print("Reject the null hypothesis: There is a significant difference between the groups.")
else:
  print("Fail to reject the null hypothesis: No significant difference between the groups.")


#step 5
# Create additional variables if needed
# For example, calculate the comment length if it's not already in your data
df['comment_length'] = df['Comment'].apply(len)
# Checking correlations between sentiment and comment length
pearson_corr, pearson_p_value = pearsonr(df['sentiment'], df['comment_length'])
spearman_corr, spearman_p_value = spearmanr(df['sentiment'], df['comment_length'])
print(f"Pearson Correlation between Sentiment and Comment Length: {pearson_corr:.4f},P-Value: {pearson_p_value:.4f}")
print(f"Spearman Correlation between Sentiment and Comment Length:{spearman_corr:.4f}, P-Value: {spearman_p_value:.4f}")
print()
# Visualizing the correlation with a scatter plot
plt.figure(figsize=(6, 4))
sns.scatterplot(x='comment_length', y='sentiment', data=df)
plt.title('Scatter Plot of Sentiment vs. Comment Length')
plt.show()
print()

#step 5
# Scatter plot with Pearson correlation line
plt.figure(figsize=(6, 4))
sns.scatterplot(x='comment_length', y='sentiment', data=df, alpha=0.5)
sns.regplot(x='comment_length', y='sentiment', data=df, scatter=False, color='r')
plt.title(f'Scatter Plot with Pearson Correlation (r={pearson_corr:.2f})')
plt.xlabel('Comment Length')
plt.ylabel('Sentiment')
plt.show()
print()
# Scatter plot with Spearman correlation line (non-parametric)
plt.figure(figsize=(6, 4))
sns.scatterplot(x='comment_length', y='sentiment', data=df, alpha=0.5)
sns.lineplot(x='comment_length', y='sentiment',
data=df.sort_values(by='comment_length'), color='r')
plt.title(f'Scatter Plot with Spearman Correlation (rho={spearman_corr:.2f})')
plt.xlabel('Comment Length')
plt.ylabel('Sentiment')
plt.show()
# Out:
# Shapiro-Wilk Test Statistic: 0.3488, P-Value: 0.0000
# Data is not normally distributed (Reject H0).
# Levene's Test Statistic: 15.4435, P-Value: 0.0000
# Variances are not equal (Reject H0).
# Kruskal-Wallis H Statistic: 46.4851, P-Value:0.0000
# Reject the null hypothesis: There is a significant difference between the groups.
# Pearson Correlation between Sentiment and Comment Length: 0.2443,P-Value: 0.0000
# Spearman Correlation between Sentiment and Comment Length:0.2341, P-Value: 0.0000

# %%
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.stats import levene
from scipy.stats import kruskal
from scipy.stats import pearsonr, spearmanr

#step 1
df = pd.read_excel('/mnt/Foaming facewash_final.xlsx')
sentiment_scores = df['sentiment'].values
# Replace 'sentiment_column' with your actual column name
# Define your benchmark value
benchmark_value = 0.0 # Example benchmark, use this
# Perform the one-sample t-test
mean_score = np.mean(sentiment_scores)
std_dev = np.std(sentiment_scores, ddof=1) # Sample standard deviation
n = len(sentiment_scores)


#step 2
# Assuming you have your sentiment scores in a Pandas DataFrame
sentiment_scores = df['sentiment']
# Shapiro-Wilk Test
stat, p_value = shapiro(sentiment_scores)
print(f"\nShapiro-Wilk Test Statistic: {stat:.4f}, P-Value: {p_value:.4f}")
# Interpret the p-value
if p_value > 0.05:
 print("Data is normally distributed (Fail to reject H0).")
else:
 print("Data is not normally distributed (Reject H0).")
print()
# Q-Q Plot
plt.figure(figsize=(6, 4))
stats.probplot(sentiment_scores, dist="norm", plot=plt)
plt.show()
# Histogram
plt.figure(figsize=(6, 4))
print()
sns.histplot(sentiment_scores, kde=True)
plt.show()


#step 3
# Assuming you have sentiment scores grouped by database
grouped_sentiments = [group['sentiment'] for name, group in df.groupby('website')]
# Levene's Test for equal variances
stat, p_value = levene(*grouped_sentiments)
print(f"\nLevene's Test Statistic: {stat:.4f}, P-Value: {p_value:.4f}")
# Interpret the p-value
if p_value > 0.05:
 print("Variances are equal (Fail to reject H0).")
else:
 print("Variances are not equal (Reject H0).")


#step 4
h_statistic, kruskal_p_value = kruskal(*grouped_sentiments)
print(f"Kruskal-Wallis H Statistic: {h_statistic:.4f}, P-Value:{kruskal_p_value:.4f}")
if kruskal_p_value < 0.05:
  print("Reject the null hypothesis: There is a significant difference between the groups.")
else:
  print("Fail to reject the null hypothesis: No significant difference between the groups.")


#step 5
# Create additional variables if needed
# For example, calculate the comment length if it's not already in your data
df['comment_length'] = df['Comment'].apply(len)
# Checking correlations between sentiment and comment length
pearson_corr, pearson_p_value = pearsonr(df['sentiment'], df['comment_length'])
spearman_corr, spearman_p_value = spearmanr(df['sentiment'], df['comment_length'])
print(f"Pearson Correlation between Sentiment and Comment Length: {pearson_corr:.4f},P-Value: {pearson_p_value:.4f}")
print(f"Spearman Correlation between Sentiment and Comment Length:{spearman_corr:.4f}, P-Value: {spearman_p_value:.4f}")
print()
# Visualizing the correlation with a scatter plot
plt.figure(figsize=(6, 4))
sns.scatterplot(x='comment_length', y='sentiment', data=df)
plt.title('Scatter Plot of Sentiment vs. Comment Length')
plt.show()
print()

#step 5
# Scatter plot with Pearson correlation line
plt.figure(figsize=(6, 4))
sns.scatterplot(x='comment_length', y='sentiment', data=df, alpha=0.5)
sns.regplot(x='comment_length', y='sentiment', data=df, scatter=False, color='r')
plt.title(f'Scatter Plot with Pearson Correlation (r={pearson_corr:.2f})')
plt.xlabel('Comment Length')
plt.ylabel('Sentiment')
plt.show()
print()
# Scatter plot with Spearman correlation line (non-parametric)
plt.figure(figsize=(6, 4))
sns.scatterplot(x='comment_length', y='sentiment', data=df, alpha=0.5)
sns.lineplot(x='comment_length', y='sentiment',
data=df.sort_values(by='comment_length'), color='r')
plt.title(f'Scatter Plot with Spearman Correlation (rho={spearman_corr:.2f})')
plt.xlabel('Comment Length')
plt.ylabel('Sentiment')
plt.show()
# Out:
# Shapiro-Wilk Test Statistic: 0.2715, P-Value: 0.0000
# Data is not normally distributed (Reject H0).
# Levene's Test Statistic: 0.5017, P-Value: 0.6057
# Variances are equal (Fail to reject H0).
# Kruskal-Wallis H Statistic: 1.0045, P-Value:0.6052
# Fail to reject the null hypothesis: No significant difference between the groups.
# Pearson Correlation between Sentiment and Comment Length: 0.1712,P-Value: 0.0000
# Spearman Correlation between Sentiment and Comment Length:0.1722, P-Value: 0.0000

# %%
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.stats import levene
from scipy.stats import kruskal
from scipy.stats import pearsonr, spearmanr

#step 1
df = pd.read_excel('/mnt/matte liquid lipstick_final.xlsx')
sentiment_scores = df['sentiment'].values
# Replace 'sentiment_column' with your actual column name
# Define your benchmark value
benchmark_value = 0.0 # Example benchmark, use this
# Perform the one-sample t-test
mean_score = np.mean(sentiment_scores)
std_dev = np.std(sentiment_scores, ddof=1) # Sample standard deviation
n = len(sentiment_scores)


#step 2
# Assuming you have your sentiment scores in a Pandas DataFrame
sentiment_scores = df['sentiment']
# Shapiro-Wilk Test
stat, p_value = shapiro(sentiment_scores)
print(f"\nShapiro-Wilk Test Statistic: {stat:.4f}, P-Value: {p_value:.4f}")
# Interpret the p-value
if p_value > 0.05:
 print("Data is normally distributed (Fail to reject H0).")
else:
 print("Data is not normally distributed (Reject H0).")
print()
# Q-Q Plot
plt.figure(figsize=(6, 4))
stats.probplot(sentiment_scores, dist="norm", plot=plt)
plt.show()
# Histogram
plt.figure(figsize=(6, 4))
print()
sns.histplot(sentiment_scores, kde=True)
plt.show()


#step 3
# Assuming you have sentiment scores grouped by database
grouped_sentiments = [group['sentiment'] for name, group in df.groupby('website')]
# Levene's Test for equal variances
stat, p_value = levene(*grouped_sentiments)
print(f"\nLevene's Test Statistic: {stat:.4f}, P-Value: {p_value:.4f}")
# Interpret the p-value
if p_value > 0.05:
 print("Variances are equal (Fail to reject H0).")
else:
 print("Variances are not equal (Reject H0).")


#step 4
h_statistic, kruskal_p_value = kruskal(*grouped_sentiments)
print(f"Kruskal-Wallis H Statistic: {h_statistic:.4f}, P-Value:{kruskal_p_value:.4f}")
if kruskal_p_value < 0.05:
  print("Reject the null hypothesis: There is a significant difference between the groups.")
else:
  print("Fail to reject the null hypothesis: No significant difference between the groups.")


#step 5
# Create additional variables if needed
# For example, calculate the comment length if it's not already in your data
df['comment_length'] = df['comment'].apply(len)
# Checking correlations between sentiment and comment length
pearson_corr, pearson_p_value = pearsonr(df['sentiment'], df['comment_length'])
spearman_corr, spearman_p_value = spearmanr(df['sentiment'], df['comment_length'])
print(f"Pearson Correlation between Sentiment and Comment Length: {pearson_corr:.4f},P-Value: {pearson_p_value:.4f}")
print(f"Spearman Correlation between Sentiment and Comment Length:{spearman_corr:.4f}, P-Value: {spearman_p_value:.4f}")
print()
# Visualizing the correlation with a scatter plot
plt.figure(figsize=(6, 4))
sns.scatterplot(x='comment_length', y='sentiment', data=df)
plt.title('Scatter Plot of Sentiment vs. Comment Length')
plt.show()
print()

#step 5
# Scatter plot with Pearson correlation line
plt.figure(figsize=(6, 4))
sns.scatterplot(x='comment_length', y='sentiment', data=df, alpha=0.5)
sns.regplot(x='comment_length', y='sentiment', data=df, scatter=False, color='r')
plt.title(f'Scatter Plot with Pearson Correlation (r={pearson_corr:.2f})')
plt.xlabel('Comment Length')
plt.ylabel('Sentiment')
plt.show()
print()
# Scatter plot with Spearman correlation line (non-parametric)
plt.figure(figsize=(6, 4))
sns.scatterplot(x='comment_length', y='sentiment', data=df, alpha=0.5)
sns.lineplot(x='comment_length', y='sentiment',
data=df.sort_values(by='comment_length'), color='r')
plt.title(f'Scatter Plot with Spearman Correlation (rho={spearman_corr:.2f})')
plt.xlabel('Comment Length')
plt.ylabel('Sentiment')
plt.show()
# Out:
# Shapiro-Wilk Test Statistic: 0.2575, P-Value: 0.0000
# Data is not normally distributed (Reject H0).
# Levene's Test Statistic: 6.7908, P-Value: 0.0002
# Variances are not equal (Reject H0).
# Kruskal-Wallis H Statistic: 19.9857, P-Value:0.0002
# Reject the null hypothesis: There is a significant difference between the groups.
# Pearson Correlation between Sentiment and Comment Length: 0.1323,P-Value: 0.0001
# Spearman Correlation between Sentiment and Comment Length:0.1768, P-Value: 0.0000

# %%
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.stats import levene
from scipy.stats import kruskal
from scipy.stats import pearsonr, spearmanr

#step 1
df = pd.read_excel('/mnt/Highlighter_final.xlsx')
sentiment_scores = df['sentiment'].values
# Replace 'sentiment_column' with your actual column name
# Define your benchmark value
benchmark_value = 0.0 # Example benchmark, use this
# Perform the one-sample t-test
mean_score = np.mean(sentiment_scores)
std_dev = np.std(sentiment_scores, ddof=1) # Sample standard deviation
n = len(sentiment_scores)


#step 2
# Assuming you have your sentiment scores in a Pandas DataFrame
sentiment_scores = df['sentiment']
# Shapiro-Wilk Test
stat, p_value = shapiro(sentiment_scores)
print(f"\nShapiro-Wilk Test Statistic: {stat:.4f}, P-Value: {p_value:.4f}")
# Interpret the p-value
if p_value > 0.05:
 print("Data is normally distributed (Fail to reject H0).")
else:
 print("Data is not normally distributed (Reject H0).")
print()
# Q-Q Plot
plt.figure(figsize=(6, 4))
stats.probplot(sentiment_scores, dist="norm", plot=plt)
plt.show()
# Histogram
plt.figure(figsize=(6, 4))
print()
sns.histplot(sentiment_scores, kde=True)
plt.show()


#step 3
# Assuming you have sentiment scores grouped by database
# Ensure 'website' column has at least two unique non-empty groups
grouped_sentiments = [group['sentiment'] for name, group in df.groupby('website') if len(group) > 0]  # Filter out empty groups

# Check the number of groups
num_groups = len(grouped_sentiments)
print(f"Number of groups for Levene's test: {num_groups}")  # Print the number of groups

# Proceed with Levene's Test and Kruskal-Wallis only if there are at least 2 groups
if num_groups >= 2:
    stat, p_value = levene(*grouped_sentiments)
    print(f"\nLevene's Test Statistic: {stat:.4f}, P-Value: {p_value:.4f}")
    # Interpret the p-value
    if p_value > 0.05:
        print("Variances are equal (Fail to reject H0).")
    else:
        print("Variances are not equal (Reject H0).")

    #step 4
    h_statistic, kruskal_p_value = kruskal(*grouped_sentiments)
    print(f"Kruskal-Wallis H Statistic: {h_statistic:.4f}, P-Value:{kruskal_p_value:.4f}")
    if kruskal_p_value < 0.05:
        print("Reject the null hypothesis: There is a significant difference between the groups.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between the groups.")
else:
    print("\nInsufficient groups for Levene's and Kruskal-Wallis tests. Check the 'website' column for unique values and empty groups.")


#step 5
# Create additional variables if needed
# For example, calculate the comment length if it's not already in your data
df['comment_length'] = df['comments'].apply(len)
# Checking correlations between sentiment and comment length
pearson_corr, pearson_p_value = pearsonr(df['sentiment'], df['comment_length'])
spearman_corr, spearman_p_value = spearmanr(df['sentiment'], df['comment_length'])
print(f"Pearson Correlation between Sentiment and Comment Length: {pearson_corr:.4f},P-Value: {pearson_p_value:.4f}")
print(f"Spearman Correlation between Sentiment and Comment Length:{spearman_corr:.4f}, P-Value: {spearman_p_value:.4f}")
print()
# Visualizing the correlation with a scatter plot
plt.figure(figsize=(6, 4))
sns.scatterplot(x='comment_length', y='sentiment', data=df)
plt.title('Scatter Plot of Sentiment vs. Comment Length')
plt.show()
print()

#step 5
# Scatter plot with Pearson correlation line
plt.figure(figsize=(6, 4))
sns.scatterplot(x='comment_length', y='sentiment', data=df, alpha=0.5)
sns.regplot(x='comment_length', y='sentiment', data=df, scatter=False, color='r')
plt.title(f'Scatter Plot with Pearson Correlation (r={pearson_corr:.2f})')
plt.xlabel('Comment Length')
plt.ylabel('Sentiment')
plt.show()
print()
# Scatter plot with Spearman correlation line (non-parametric)
plt.figure(figsize=(6, 4))
sns.scatterplot(x='comment_length', y='sentiment', data=df, alpha=0.5)
sns.lineplot(x='comment_length', y='sentiment',
data=df.sort_values(by='comment_length'), color='r')
plt.title(f'Scatter Plot with Spearman Correlation (rho={spearman_corr:.2f})')
plt.xlabel('Comment Length')
plt.ylabel('Sentiment')
plt.show()
# Out:
# Shapiro-Wilk Test Statistic: 0.2902, P-Value: 0.0000
# Data is not normally distributed (Reject H0).
# Number of groups for Levene's test: 1
#
# Insufficient groups for Levene's and Kruskal-Wallis tests. Check the 'website' column for unique values and empty groups.
# Pearson Correlation between Sentiment and Comment Length: -0.1231,P-Value: 0.0002
# Spearman Correlation between Sentiment and Comment Length:-0.0791, P-Value: 0.0177

# %%
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.stats import levene
from scipy.stats import kruskal
from scipy.stats import pearsonr, spearmanr

#step 1
df = pd.read_excel('/mnt/Blush_final.xlsx')
sentiment_scores = df['sentiment'].values
# Replace 'sentiment_column' with your actual column name
# Define your benchmark value
benchmark_value = 0.0 # Example benchmark, use this
# Perform the one-sample t-test
mean_score = np.mean(sentiment_scores)
std_dev = np.std(sentiment_scores, ddof=1) # Sample standard deviation
n = len(sentiment_scores)


#step 2
# Assuming you have your sentiment scores in a Pandas DataFrame
sentiment_scores = df['sentiment']
# Shapiro-Wilk Test
stat, p_value = shapiro(sentiment_scores)
print(f"\nShapiro-Wilk Test Statistic: {stat:.4f}, P-Value: {p_value:.4f}")
# Interpret the p-value
if p_value > 0.05:
 print("Data is normally distributed (Fail to reject H0).")
else:
 print("Data is not normally distributed (Reject H0).")
print()
# Q-Q Plot
plt.figure(figsize=(6, 4))
stats.probplot(sentiment_scores, dist="norm", plot=plt)
plt.show()
# Histogram
plt.figure(figsize=(6, 4))
print()
sns.histplot(sentiment_scores, kde=True)
plt.show()


#step 3
# Assuming you have sentiment scores grouped by database
# Ensure 'website' column has at least two unique non-empty groups
grouped_sentiments = [group['sentiment'] for name, group in df.groupby('Website name') if len(group) > 0]  # Filter out empty groups

# Check the number of groups
num_groups = len(grouped_sentiments)
print(f"Number of groups for Levene's test: {num_groups}")  # Print the number of groups

# Proceed with Levene's Test and Kruskal-Wallis only if there are at least 2 groups
if num_groups >= 2:
    stat, p_value = levene(*grouped_sentiments)
    print(f"\nLevene's Test Statistic: {stat:.4f}, P-Value: {p_value:.4f}")
    # Interpret the p-value
    if p_value > 0.05:
        print("Variances are equal (Fail to reject H0).")
    else:
        print("Variances are not equal (Reject H0).")

    #step 4
    h_statistic, kruskal_p_value = kruskal(*grouped_sentiments)
    print(f"Kruskal-Wallis H Statistic: {h_statistic:.4f}, P-Value:{kruskal_p_value:.4f}")
    if kruskal_p_value < 0.05:
        print("Reject the null hypothesis: There is a significant difference between the groups.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between the groups.")
else:
    print("\nInsufficient groups for Levene's and Kruskal-Wallis tests. Check the 'website' column for unique values and empty groups.")


#step 5
# Create additional variables if needed
# For example, calculate the comment length if it's not already in your data
df['comment_length'] = df['COMMENT'].apply(len)
# Checking correlations between sentiment and comment length
pearson_corr, pearson_p_value = pearsonr(df['sentiment'], df['comment_length'])
spearman_corr, spearman_p_value = spearmanr(df['sentiment'], df['comment_length'])
print(f"Pearson Correlation between Sentiment and Comment Length: {pearson_corr:.4f},P-Value: {pearson_p_value:.4f}")
print(f"Spearman Correlation between Sentiment and Comment Length:{spearman_corr:.4f}, P-Value: {spearman_p_value:.4f}")
print()
# Visualizing the correlation with a scatter plot
plt.figure(figsize=(6, 4))
sns.scatterplot(x='comment_length', y='sentiment', data=df)
plt.title('Scatter Plot of Sentiment vs. Comment Length')
plt.show()
print()

#step 5
# Scatter plot with Pearson correlation line
plt.figure(figsize=(6, 4))
sns.scatterplot(x='comment_length', y='sentiment', data=df, alpha=0.5)
sns.regplot(x='comment_length', y='sentiment', data=df, scatter=False, color='r')
plt.title(f'Scatter Plot with Pearson Correlation (r={pearson_corr:.2f})')
plt.xlabel('Comment Length')
plt.ylabel('Sentiment')
plt.show()
print()
# Scatter plot with Spearman correlation line (non-parametric)
plt.figure(figsize=(6, 4))
sns.scatterplot(x='comment_length', y='sentiment', data=df, alpha=0.5)
sns.lineplot(x='comment_length', y='sentiment',
data=df.sort_values(by='comment_length'), color='r')
plt.title(f'Scatter Plot with Spearman Correlation (rho={spearman_corr:.2f})')
plt.xlabel('Comment Length')
plt.ylabel('Sentiment')
plt.show()
# Out:
# Shapiro-Wilk Test Statistic: 0.2272, P-Value: 0.0000
# Data is not normally distributed (Reject H0).
# Number of groups for Levene's test: 2
#
# Levene's Test Statistic: 2.4247, P-Value: 0.1198
# Variances are equal (Fail to reject H0).
# Kruskal-Wallis H Statistic: 2.4209, P-Value:0.1197
# Fail to reject the null hypothesis: No significant difference between the groups.
# Pearson Correlation between Sentiment and Comment Length: 0.1842,P-Value: 0.0000
# Spearman Correlation between Sentiment and Comment Length:0.1949, P-Value: 0.0000
